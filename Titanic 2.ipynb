# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import seaborn as sns
titanic = sns.load_dataset('titanic')
print(titanic.head())
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who adult_male deck  embark_town alive  alone
# 0    man       True  NaN  Southampton    no  False
# 1  woman      False    C    Cherbourg   yes  False
# 2  woman      False  NaN  Southampton   yes   True
# 3  woman      False    C  Southampton   yes  False
# 4    man       True  NaN  Southampton    no   True

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
# survived       891 non-null int64
# pclass         891 non-null int64
# sex            891 non-null object
# age            714 non-null float64
# sibsp          891 non-null int64
# parch          891 non-null int64
# fare           891 non-null float64
# embarked       889 non-null object
# class          891 non-null category
# who            891 non-null object
# adult_male     891 non-null bool
# deck           203 non-null category
# embark_town    889 non-null object
# alive          891 non-null object
# alone          891 non-null bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.2+ KB

# %%
titanic[['embarked','embark_town','deck']]
# Out:
#     embarked  embark_town deck
# 0          S  Southampton  NaN
# 1          C    Cherbourg    C
# 2          S  Southampton  NaN
# 3          S  Southampton    C
# 4          S  Southampton  NaN
# 5          Q   Queenstown  NaN
# 6          S  Southampton    E
# 7          S  Southampton  NaN
# 8          S  Southampton  NaN
# 9          C    Cherbourg  NaN
# 10         S  Southampton    G
# 11         S  Southampton    C
# 12         S  Southampton  NaN
# 13         S  Southampton  NaN
# 14         S  Southampton  NaN
# 15         S  Southampton  NaN
# 16         Q   Queenstown  NaN
# 17         S  Southampton  NaN
# 18         S  Southampton  NaN
# 19         C    Cherbourg  NaN
# 20         S  Southampton  NaN
# 21         S  Southampton    D
# 22         Q   Queenstown  NaN
# 23         S  Southampton    A
# 24         S  Southampton  NaN
# 25         S  Southampton  NaN
# 26         C    Cherbourg  NaN
# 27         S  Southampton    C
# 28         Q   Queenstown  NaN
# ...

# %%
titanic.drop(['embark_town','deck'],axis=1,inplace=True)

# %%
titanic[['age','class','sex']]
# Out:
#       age   class     sex
# 0    22.0   Third    male
# 1    38.0   First  female
# 2    26.0   Third  female
# 3    35.0   First  female
# 4    35.0   Third    male
# 5     NaN   Third    male
# 6    54.0   First    male
# 7     2.0   Third    male
# 8    27.0   Third  female
# 9    14.0  Second  female
# 10    4.0   Third  female
# 11   58.0   First  female
# 12   20.0   Third    male
# 13   39.0   Third    male
# 14   14.0   Third  female
# 15   55.0  Second  female
# 16    2.0   Third    male
# 17    NaN  Second    male
# 18   31.0   Third  female
# 19    NaN   Third  female
# 20   35.0  Second    male
# 21   34.0  Second    male
# 22   15.0   Third  female
# 23   28.0   First    male
# 24    8.0   Third  female
# 25   38.0   Third  female
# 26    NaN   Third    male
# 27   19.0   First    male
# 28    NaN   Third  female
# 29    NaN   Third    male
# ..    ...     ...     ...
# 861  21.0  Second    male
# 862  48.0   First  female
# 863   NaN   Third  female
# ...

# %%
titanic[titanic['age'] > 60]
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked   class  \
# 33          0       2    male  66.0      0      0   10.5000        S  Second
# 54          0       1    male  65.0      0      1   61.9792        C   First
# 96          0       1    male  71.0      0      0   34.6542        C   First
# 116         0       3    male  70.5      0      0    7.7500        Q   Third
# 170         0       1    male  61.0      0      0   33.5000        S   First
# 252         0       1    male  62.0      0      0   26.5500        S   First
# 275         1       1  female  63.0      1      0   77.9583        S   First
# 280         0       3    male  65.0      0      0    7.7500        Q   Third
# 326         0       3    male  61.0      0      0    6.2375        S   Third
# 438         0       1    male  64.0      1      4  263.0000        S   First
# 456         0       1    male  65.0      0      0   26.5500        S   First
# ...

# %%
titanic[titanic['age'] > 60][['sex', 'class', 'age', 'survived']]
# Out:
#         sex   class   age  survived
# 33     male  Second  66.0         0
# 54     male   First  65.0         0
# 96     male   First  71.0         0
# 116    male   Third  70.5         0
# 170    male   First  61.0         0
# 252    male   First  62.0         0
# 275  female   First  63.0         1
# 280    male   Third  65.0         0
# 326    male   Third  61.0         0
# 438    male   First  64.0         0
# 456    male   First  65.0         0
# 483  female   Third  63.0         1
# 493    male   First  71.0         0
# 545    male   First  64.0         0
# 555    male   First  62.0         0
# 570    male  Second  62.0         1
# 625    male   First  61.0         0
# 630    male   First  80.0         1
# 672    male  Second  70.0         0
# 745    male   First  70.0         0
# 829  female   First  62.0         1
# 851    male   Third  74.0         0

# %%
titanic[titanic['age'].isnull()][['sex', 'class', 'age']]
# Out:
#         sex   class  age
# 5      male   Third  NaN
# 17     male  Second  NaN
# 19   female   Third  NaN
# 26     male   Third  NaN
# 28   female   Third  NaN
# 29     male   Third  NaN
# 31   female   First  NaN
# 32   female   Third  NaN
# 36     male   Third  NaN
# 42     male   Third  NaN
# 45     male   Third  NaN
# 46     male   Third  NaN
# 47   female   Third  NaN
# 48     male   Third  NaN
# 55     male   First  NaN
# 64     male   First  NaN
# 65     male   Third  NaN
# 76     male   Third  NaN
# 77     male   Third  NaN
# 82   female   Third  NaN
# 87     male   Third  NaN
# 95     male   Third  NaN
# 101    male   Third  NaN
# 107    male   Third  NaN
# 109  female   Third  NaN
# 121    male   Third  NaN
# 126    male   Third  NaN
# 128  female   Third  NaN
# 140  female   Third  NaN
# 154    male   Third  NaN
# ..      ...     ...  ...
# 718    male   Third  NaN
# 727  female   Third  NaN
# 732    male  Second  NaN
# 738    male   Third  NaN
# 739    male   Third  NaN
# ...

# %%
for p_class in ['First','Second','Third']:
    print( p_class, len(titanic[(titanic['sex'] == 'male') & (titanic['class'] == p_class) ]))
# Out:
# First 122
# Second 108
# Third 347

# %%
titanic[titanic.sex=='male'].shape[0]
# Out:
# 577

# %%
titanic[titanic.sex=='female'].shape[0]
# Out:
# 314

# %%
titanic['age'][titanic.sex=='male'].dropna().hist(bins=16, range=(0,80), alpha = 1)
titanic['age'][titanic.sex=='female'].dropna().hist(bins=16, range=(0,80), alpha = .5)

# %%
median_ages = pd.DataFrame(data=np.zeros((2,3)),index = ['male','female'],columns=['First','Second','Third'])
median_ages
# Out:
#         First  Second  Third
# male      0.0     0.0    0.0
# female    0.0     0.0    0.0

# %%
median_ages.ix['male','Second']
# Out:
# 0.0

# %%
for sex in ['male','female']:
    for p_class in ['First','Second','Third']:
        median_ages.ix[sex,p_class] = titanic[(titanic['sex'] == sex) & (titanic['class'] == p_class)]['age'].dropna().median()

median_ages
# Out:
#         First  Second  Third
# male     40.0    30.0   25.0
# female   35.0    28.0   21.5

# %%
titanic['age_fill'] = titanic['age']

# %%
titanic[ titanic['age'].isnull() ][['sex','class','age','age_fill']].head(10)
# Out:
#        sex   class  age  age_fill
# 5     male   Third  NaN       NaN
# 17    male  Second  NaN       NaN
# 19  female   Third  NaN       NaN
# 26    male   Third  NaN       NaN
# 28  female   Third  NaN       NaN
# 29    male   Third  NaN       NaN
# 31  female   First  NaN       NaN
# 32  female   Third  NaN       NaN
# 36    male   Third  NaN       NaN
# 42    male   Third  NaN       NaN

# %%
titanic[['age','sex','class','age','age_fill']].head(10)
# Out:
#     age     sex   class   age  age_fill
# 0  22.0    male   Third  22.0      22.0
# 1  38.0  female   First  38.0      38.0
# 2  26.0  female   Third  26.0      26.0
# 3  35.0  female   First  35.0      35.0
# 4  35.0    male   Third  35.0      35.0
# 5   NaN    male   Third   NaN       NaN
# 6  54.0    male   First  54.0      54.0
# 7   2.0    male   Third   2.0       2.0
# 8  27.0  female   Third  27.0      27.0
# 9  14.0  female  Second  14.0      14.0

# %%
sex = 'male'
p_class = 'First'

titanic.loc[(titanic.age.isnull()) & (titanic.sex == sex) & (titanic['class'] == p_class),'age']
# Out:
# 55    NaN
# 64    NaN
# 168   NaN
# 185   NaN
# 270   NaN
# 284   NaN
# 295   NaN
# 298   NaN
# 351   NaN
# 475   NaN
# 507   NaN
# 527   NaN
# 557   NaN
# 602   NaN
# 633   NaN
# 711   NaN
# 740   NaN
# 766   NaN
# 793   NaN
# 815   NaN
# 839   NaN
# Name: age, dtype: float64

# %%
for sex in ['male','female']:
    for p_class in ['First','Second','Third']:
        titanic.ix[(titanic.age.isnull()) & (titanic.sex == sex) & (titanic['class'] == p_class),'age_fill'] = median_ages.ix[sex,p_class]

# %%
titanic[['sex','class','age','age_fill']].head(20)
# Out:
#        sex   class   age  age_fill
# 0     male   Third  22.0      22.0
# 1   female   First  38.0      38.0
# 2   female   Third  26.0      26.0
# 3   female   First  35.0      35.0
# 4     male   Third  35.0      35.0
# 5     male   Third   NaN      25.0
# 6     male   First  54.0      54.0
# 7     male   Third   2.0       2.0
# 8   female   Third  27.0      27.0
# 9   female  Second  14.0      14.0
# 10  female   Third   4.0       4.0
# 11  female   First  58.0      58.0
# 12    male   Third  20.0      20.0
# 13    male   Third  39.0      39.0
# 14  female   Third  14.0      14.0
# 15  female  Second  55.0      55.0
# 16    male   Third   2.0       2.0
# 17    male  Second   NaN      30.0
# 18  female   Third  31.0      31.0
# 19  female   Third   NaN      21.5

# %%
titanic.age = titanic.age_fill

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 14 columns):
# survived      891 non-null int64
# pclass        891 non-null int64
# sex           891 non-null object
# age           891 non-null float64
# sibsp         891 non-null int64
# parch         891 non-null int64
# fare          891 non-null float64
# embarked      889 non-null object
# class         891 non-null category
# who           891 non-null object
# adult_male    891 non-null bool
# alive         891 non-null object
# alone         891 non-null bool
# age_fill      891 non-null float64
# dtypes: bool(2), category(1), float64(3), int64(4), object(4)
# memory usage: 79.3+ KB

# %%
titanic.ix[titanic.embarked.isnull(),'embarked'] ='S'

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 14 columns):
# survived      891 non-null int64
# pclass        891 non-null int64
# sex           891 non-null object
# age           891 non-null float64
# sibsp         891 non-null int64
# parch         891 non-null int64
# fare          891 non-null float64
# embarked      891 non-null object
# class         891 non-null category
# who           891 non-null object
# adult_male    891 non-null bool
# alive         891 non-null object
# alone         891 non-null bool
# age_fill      891 non-null float64
# dtypes: bool(2), category(1), float64(3), int64(4), object(4)
# memory usage: 79.3+ KB

# %%
titanic['family_size'] = titanic['sibsp'] + titanic['parch']

# %%
titanic['family_size'].max()
# Out:
# 10

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked   class  \
# 0           0       3    male  22.0      1      0    7.2500        S   Third
# 1           1       1  female  38.0      1      0   71.2833        C   First
# 2           1       3  female  26.0      0      0    7.9250        S   Third
# 3           1       1  female  35.0      1      0   53.1000        S   First
# 4           0       3    male  35.0      0      0    8.0500        S   Third
# 5           0       3    male  25.0      0      0    8.4583        Q   Third
# 6           0       1    male  54.0      0      0   51.8625        S   First
# 7           0       3    male   2.0      3      1   21.0750        S   Third
# 8           1       3  female  27.0      0      2   11.1333        S   Third
# 9           1       2  female  14.0      1      0   30.0708        C  Second
# 10          1       3  female   4.0      1      1   16.7000        S   Third
# ...

# %%
titanic.drop('alive',axis=1,inplace=True)

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 14 columns):
# survived       891 non-null int64
# pclass         891 non-null int64
# sex            891 non-null object
# age            891 non-null float64
# sibsp          891 non-null int64
# parch          891 non-null int64
# fare           891 non-null float64
# embarked       891 non-null object
# class          891 non-null category
# who            891 non-null object
# adult_male     891 non-null bool
# alone          891 non-null bool
# age_fill       891 non-null float64
# family_size    891 non-null int64
# dtypes: bool(2), category(1), float64(3), int64(5), object(3)
# memory usage: 79.3+ KB

# %%
train = titanic.copy()

# %%
from sklearn import preprocessing

lb_sex = preprocessing.LabelEncoder()
lb_sex.fit(titanic['sex'])
titanic['sex'] = lb_sex.transform(titanic['sex'])

lb_embarked = preprocessing.LabelEncoder()
lb_embarked.fit(titanic['embarked'])
titanic['embarked'] = lb_embarked.transform(titanic['embarked'])

lb_class = preprocessing.LabelEncoder()
lb_class.fit(titanic['class'])
titanic['class'] = lb_class.transform(titanic['class'])

lb_who = preprocessing.LabelEncoder()
lb_who.fit(titanic['who'])
titanic['who'] = lb_who.transform(titanic['who'])

lb_adult_male = preprocessing.LabelEncoder()
lb_adult_male.fit(titanic['adult_male'])
titanic['adult_male'] = lb_adult_male.transform(titanic['adult_male'])

lb_alone = preprocessing.LabelEncoder()
lb_alone.fit(titanic['alone'])
titanic['alone'] = lb_alone.transform(titanic['alone'])

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 14 columns):
# survived       891 non-null int64
# pclass         891 non-null int64
# sex            891 non-null int64
# age            891 non-null float64
# sibsp          891 non-null int64
# parch          891 non-null int64
# fare           891 non-null float64
# embarked       891 non-null int64
# class          891 non-null int64
# who            891 non-null int64
# adult_male     891 non-null int64
# alone          891 non-null int64
# age_fill       891 non-null float64
# family_size    891 non-null int64
# dtypes: float64(3), int64(11)
# memory usage: 97.5 KB

# %%
y = titanic.values[:,0]

# %%
X = titanic.values[:,1:]

# %%
import sklearn

# %%
X_train, X_test, y_train, y_test = sklearn.cross_validation.train_test_split(X, y , test_size = .33)

# %%
# Import the random forest package
from sklearn.ensemble import RandomForestClassifier 

# Create the random forest object which will include all the parameters
# for the fit
forest = RandomForestClassifier(n_estimators = 300)

# Fit the training data to the Survived labels and create the decision trees
forest = forest.fit(X_train,y_train)

# Take the same decision trees and run it on the test data
y_pred = forest.predict(X_test)

# %%
sklearn.metrics.accuracy_score(y_pred, y_test)
# Out:
# 0.81694915254237288

# %%
print(sklearn.metrics.classification_report(y_test, y_pred))
# Out:
#              precision    recall  f1-score   support
#
#         0.0       0.86      0.85      0.86       191
#         1.0       0.74      0.75      0.74       104
#
# avg / total       0.82      0.82      0.82       295

# %%
sklearn.metrics.confusion_matrix(y_test, y_pred)
# Out:
# array([[163,  28],
#        [ 26,  78]])
